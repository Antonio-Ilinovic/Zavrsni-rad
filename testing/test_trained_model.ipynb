# %%
import matplotlib.pyplot as plt

import Utils
import evaluate

# %%
IMAGE_INDEX = 5

trained_model = Utils.load_model('D:/ZAVRSNI/Kodovi/trained_models/margin_is_0_2/trained_model.pth')
real_disp = Utils.get_disp_image(IMAGE_INDEX)
pred_disp = evaluate.predict_disparity_map(IMAGE_INDEX, trained_model, 5)

plt.figure(figsize=(20,10))
plt.subplot(2, 1, 1)
plt.imshow(real_disp)
plt.colorbar()
plt.subplot(2, 1, 2)
plt.imshow(pred_disp)
plt.colorbar()
