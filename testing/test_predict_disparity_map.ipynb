# %%
import Evaluate
import Utils
import Network
import matplotlib.pyplot as plt
import Accuracy
import numpy as np

from matplotlib import colors

# %%
image_num = 5
trained_model = Utils.load_model('D:/ZAVRSNI/Kodovi/trained_model.pth')
untrained_model = Network.Conv64Features()
D = 100

# %%
real_disp = Utils.get_disp_image(image_num)
predicted_disp = Evaluate.predict_disparity_map(image_num, trained_model, D)

# %%
plt.figure(figsize=(20,10))
plt.subplot(2, 1, 1)
plt.imshow(real_disp, cmap="hot", vmin=0, vmax=100)
plt.colorbar()
plt.subplot(2, 1, 2)
plt.imshow(predicted_disp, cmap="hot", vmin=0, vmax=100)
plt.colorbar()

# %%
left = Utils.get_left_image(image_num)
plt.imshow(left)

# %%
cut_pixels = 4
real_disp_cut = real_disp[cut_pixels:-cut_pixels, cut_pixels:-cut_pixels]

# %%
acc_disp = Accuracy.calculate_accuracy(real_disp_cut, predicted_disp)
Accuracy.plot_accuracy(acc_disp)
